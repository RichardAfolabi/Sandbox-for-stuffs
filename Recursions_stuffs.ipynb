# %% [markdown]
# # Recursion

# %% [markdown]
# ### Recursive algorithm that finds the size of directories and subdirectories given a path.

# %%
import os

def disk_usage(path):
    """ Return zise of file/folder in a directory """

    total = os.path.getsize(path)
    if os.path.isdir(path):
        for filename in os.listdir(path):
            childpath = os.path.join(path, filename)
            total += disk_usage(childpath)
            
    print('{0:<7}'.format(total), path)
    return total


# Call function with specific path
disk_usage("/Users/")

# %% [markdown]
# ## Recursive algorithm to find the maximum element in a sequence of n elements

# %% [markdown]
# If the sequence is ordered (or sorted), then it could be ascending or descending. If ascending, the $S[1]$ element is the maximum and if DESCending, the $S[n]$ elment is maxium. In both cases the runing time is $O(1)$ or $\Omega(1)$ constant time.
#
# If the sequence is NOT ordered, then the maximum could be anywhere. The runing time in the worst case is $O(n)$

# %% [markdown]
# ### Non-recursive

# %%
def find_maximus(S):
    """ Linear search for maximum element"""
    if len(S) < 1:
        return "Invalid input"
    elif len(S) == 1:
        return S[len(S)-1]
    else:
        for k in range(len(S) - 1):
            if S[k] > S[k-1]:
                elmax = S[k]
        return elmax


indata = [4,2, 1, 4, 6, 8, 0]
find_maximus(indata)
# Out:
# 8

# %% [markdown]
# ### Recursive

# %%
def binary_find_maximum(S, start, stop):
    """ Find maximum element in a sequence of n-elements.
    We use Binary recursion. Find the max(max(half_1), max(half_2)) """
    # when no element exist in the sequence
    if start > stop:
        return 0
    #when only 1 element exist in the sequence
    elif start == stop:
        return S[start]
    #There are at least two elements in the sequence
    else:
        mid = (start + stop) // 2
        if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
            return binary_find_maximum(S, start, mid)
        else:
            return binary_find_maximum(S, mid, stop)
    

indata = [4,2, 1, 4, 6, 8, 0]
binary_find_maximum(indata, 0, len(indata)-1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-4c1fb59ebbb6> in <module>()
#      18
#      19 indata = [4,2, 1, 4, 6, 8, 0]
# ---> 20 binary_find_maximum(indata, 0, len(indata)-1)
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
# ...
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#      11     else:
#      12         mid = (start + stop) // 2
# ---> 13         if binary_find_maximum(S, start, mid) > binary_find_maximum(S, mid, stop):
#      14             return binary_find_maximum(S, start, mid)
#      15         else:
#
# <ipython-input-33-4c1fb59ebbb6> in binary_find_maximum(S, start, stop)
#       3     We use Binary recursion. Find the max(max(half_1), max(half_2)) """
#       4     # when no element exist in the sequence
# ----> 5     if start > stop:
#       6         return 0
#       7     #when only 1 element exist in the sequence
#
# RuntimeError: maximum recursion depth exceeded in comparison
